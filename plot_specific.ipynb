# %% [markdown]
# # Specific images

# %%
import matplotlib.pyplot as plt
import matplotlib

from skimage import data

matplotlib.rcParams["font.size"] = 18

# %% [markdown]
# ## Stereo images

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))
ax = axes.ravel()

cycle_images = data.stereo_motorcycle()
ax[0].imshow(cycle_images[0])
ax[1].imshow(cycle_images[1])

fig.tight_layout()
plt.show()

# %% [markdown]
# ## PIV images

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))
ax = axes.ravel()

vortex_images = data.vortex()
ax[0].imshow(vortex_images[0])
ax[1].imshow(vortex_images[1])

fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11668\2226754239.py in <module>
#       2 ax = axes.ravel()
#       3
# ----> 4 vortex_images = data.vortex()
#       5 ax[0].imshow(vortex_images[0])
#       6 ax[1].imshow(vortex_images[1])
#
# c:\Users\matte\anaconda3\lib\site-packages\skimage\data\_fetchers.py in vortex()
#    1246     .. [2] 1st PIV challenge Case B: http://pivchallenge.org/pub/index.html#b
#    1247     """
# -> 1248     return (_load('data/pivchallenge-B-B001_1.tif'),
#    1249             _load('data/pivchallenge-B-B001_2.tif'))
#
# c:\Users\matte\anaconda3\lib\site-packages\skimage\data\_fetchers.py in _load(f, as_gray)
#     357     # we lazy import it here
#     358     from ..io import imread
# --> 359     return imread(_fetch(f), as_gray=as_gray)
#     360
#     361
#
# c:\Users\matte\anaconda3\lib\site-packages\skimage\data\_fetchers.py in _fetch(data_filename)
#     217         _skip_pytest_case_requiring_pooch(data_filename)
#     218
# --> 219         raise ModuleNotFoundError(
#     220             "The requested file is part of the scikit-image distribution, "
#     221             "but requires the installation of an optional dependency, pooch. "
#
# ModuleNotFoundError: The requested file is part of the scikit-image distribution, but requires the installation of an optional dependency, pooch. To install pooch, use your preferred python package manager. Follow installation instruction found at https://scikit-image.org/docs/stable/install.html

# %% [markdown]
# ## Faces and non-faces dataset
#
# A sample of 20 over 200 images is displayed.

# %%
fig, axes = plt.subplots(4, 5, figsize=(20, 20))
ax = axes.ravel()
lfw_images = data.lfw_subset()
for i in range(20):
    ax[i].imshow(lfw_images[90 + i], cmap=plt.cm.gray)
    ax[i].axis("off")
fig.tight_layout()
plt.show()

# %% [markdown]
# Thumbnail image for the gallery

# %%
from matplotlib.offsetbox import AnchoredText

# Create a gridspec with two images in the first and 4 in the second row
fig, axd = plt.subplot_mosaic(
    [["stereo", "stereo", "piv", "piv"], ["lfw0", "lfw1", "lfw2", "lfw3"]],
)
axd["stereo"].imshow(cycle_images[0])
axd["stereo"].add_artist(
    AnchoredText(
        "Stereo",
        prop=dict(size=20),
        frameon=True,
        borderpad=0,
        loc="upper left",
    )
)
axd["piv"].imshow(vortex_images[0])
axd["piv"].add_artist(
    AnchoredText(
        "PIV",
        prop=dict(size=20),
        frameon=True,
        borderpad=0,
        loc="upper left",
    )
)
axd["lfw0"].imshow(lfw_images[91], cmap="gray")
axd["lfw1"].imshow(lfw_images[92], cmap="gray")
axd["lfw2"].imshow(lfw_images[93], cmap="gray")
axd["lfw3"].imshow(lfw_images[94], cmap="gray")

for ax in axd.values():
    ax.axis("off")
fig.tight_layout()
plt.show()
